# %%
import sqlite3, pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.graphics as smg
import pandas as pd
from pandas.plotting import parallel_coordinates, scatter_matrix
from scipy import stats
path = '' # fill in the data path

# %%
# 根据格式把表格读进来
#要是csv能直接读，要是db文件需要用sql指令
#csv的指令
# df = pd.read_csv(path_data)

# %%
#db的指令
# conn = sqlite3.connect(path）
# df=pd.read_sql_query("""里面填sql指令""", conn)

# %%
depedent_variable = []#自变量名称
variables = depedent_variable + [] #因变量
data = df[variables]
pearsonCorr = data.corr()
names = pearsonCorr.index.tolist()
pearsonCorr
#如果填完了还报错直接扔给ai
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 depedent_variable = []#自变量名称
#       2 variables = depedent_variable + [] #因变量
# ----> 3 data = df[variables]
#       4 pearsonCorr = data.corr()
#       5 names = pearsonCorr.index.tolist()
#
# NameError: name 'df' is not defined

# %%
#第一步，去除无关的自变量，表格上近似于0的无线性，不会看上面那个看下面这个热力图
plt.figure()
plt.matshow(pearsonCorr)
plt.clim(-1.,1.)
plt.colorbar()
plt.xticks(range(len(names)), names, rotation=90)
plt.yticks(range(len(names)), names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 #第一步，去除无关的自变量，表格上近似于0的无线性，不会看上面那个看下面这个热力图
#       2 plt.figure()
# ----> 3 plt.matshow(pearsonCorr)
#       4 plt.clim(-1.,1.)
#       5 plt.colorbar()
#
# NameError: name 'pearsonCorr' is not defined

# %%
#第二步，看图，检测是否有非线性关系
plt.figure()
scatter_matrix(data[names], diagonal='kde')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 #第二步，看图，检测是否有非线性关系
#       2 plt.figure()
# ----> 3 scatter_matrix(data[names], diagonal='kde')
#
# NameError: name 'scatter_matrix' is not defined

# %%
#第三步，看是否有重叠自变量
depedent_variable_new = [] #新的自变量
data = df[depedent_variable_new]
pearsonCorr = data.corr()
names = pearsonCorr.index.tolist()
pearsonCorr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 #第三步，看是否有重叠自变量
#       2 depedent_variable_new = [] #新的自变量
# ----> 3 data = df[depedent_variable_new]
#       4 pearsonCorr = data.corr()
#       5 names = pearsonCorr.index.tolist()
#
# NameError: name 'df' is not defined

# %%
#摆烂，做个线性差不多得了，拿钱肯定别想了
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import numpy as np
import pandas as pd
data = df
model = smf.ols('因变量 ~ 自变量', data=data)
results = model.fit()
print(results.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 8
#       6 import numpy as np
#       7 import pandas as pd
# ----> 8 data = df
#       9 model = smf.ols('因变量 ~ 自变量', data=data)
#      10 results = model.fit()
#
# NameError: name 'df' is not defined

# %%
# R^2 越da
